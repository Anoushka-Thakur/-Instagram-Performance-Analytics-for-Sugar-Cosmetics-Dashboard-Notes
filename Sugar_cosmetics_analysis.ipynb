# %% [markdown]
# Sugar Cosmetics Analysis

# %%
# Load the library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the csv file
data = pd.read_csv('Sugar_cosmetics_instagram_data.csv')

# %%
data.head()
# Out:
#     Post Date Post Type   Campaign Type  \
# 0  2024-12-23     Story        Giveaway
# 1  2024-06-01     Image        Tutorial
# 2  2024-04-28      Reel   Festive Offer
# 3  2025-02-01      Reel  Product Launch
# 4  2024-08-04     Story        Tutorial
#
#                                       Hashtags Audience Emotion  \
# 0    #SugarCosmetics, #MakeupGoals, #BoldLooks          Curious
# 1       #BoldLooks, #MakeupGoals, #VeganBeauty        Confident
# 2                                 #VeganBeauty        Confident
# 3  #CrueltyFree, #VeganBeauty, #SugarCosmetics            Happy
# 4                #SugarCosmetics, #VeganBeauty          Curious
#
#   Engagement Source  Impressions  Reach  Likes  Comments  Shares  Saves  \
# 0            Collab        16795  15665   3076       430      73     99
# 1        Influencer        45131  29335   5285       308     396    502
# 2            Collab        18568  13118   2032       233      73    140
# ...

# %%
# check missing values, null values, duplicated, etc.
print("\n Data Info:")
print(data.info())
# Out:
#  Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Post Date          50000 non-null  object
#  1   Post Type          50000 non-null  object
#  2   Campaign Type      50000 non-null  object
#  3   Hashtags           50000 non-null  object
#  4   Audience Emotion   50000 non-null  object
#  5   Engagement Source  50000 non-null  object
#  6   Impressions        50000 non-null  int64
#  7   Reach              50000 non-null  int64
#  8   Likes              50000 non-null  int64
#  9   Comments           50000 non-null  int64
#  10  Shares             50000 non-null  int64
#  11  Saves              50000 non-null  int64
#  12  Profile Visits     50000 non-null  int64
#  13  Follows            50000 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 5.3+ MB
# None

# %%
# change the Post Date column to datetime format
data['Post Date'] = pd.to_datetime(data['Post Date'], errors='coerce')
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Post Date          50000 non-null  datetime64[ns]
#  1   Post Type          50000 non-null  object
#  2   Campaign Type      50000 non-null  object
#  3   Hashtags           50000 non-null  object
#  4   Audience Emotion   50000 non-null  object
#  5   Engagement Source  50000 non-null  object
#  6   Impressions        50000 non-null  int64
#  7   Reach              50000 non-null  int64
#  8   Likes              50000 non-null  int64
#  9   Comments           50000 non-null  int64
#  10  Shares             50000 non-null  int64
#  11  Saves              50000 non-null  int64
#  12  Profile Visits     50000 non-null  int64
#  13  Follows            50000 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(5)
# memory usage: 5.3+ MB
# None

# %%
print("\n Null values:")
print(data.isnull().sum())
# Out:
#  Null values:
# Post Date            0
# Post Type            0
# Campaign Type        0
# Hashtags             0
# Audience Emotion     0
# Engagement Source    0
# Impressions          0
# Reach                0
# Likes                0
# Comments             0
# Shares               0
# Saves                0
# Profile Visits       0
# Follows              0
# dtype: int64

# %%
print("\n Duplicated values:")
print(data.duplicated().sum())
# Out:
#  Duplicated values:
# 0

# %%
data.describe()
# Out:
#                            Post Date   Impressions         Reach  \
# count                          50000  50000.000000  50000.000000
# mean   2024-10-17 22:51:23.904000512  25520.915000  19748.465760
# min              2024-04-19 00:00:00   1002.000000    616.000000
# 25%              2024-07-18 00:00:00  13243.000000  10157.750000
# 50%              2024-10-18 00:00:00  25541.000000  19393.500000
# 75%              2025-01-17 00:00:00  37758.250000  28763.250000
# max              2025-04-19 00:00:00  49999.000000  47329.000000
# std                              NaN  14118.653466  11311.962456
#
#               Likes      Comments        Shares        Saves  Profile Visits  \
# count  50000.000000  50000.000000  50000.000000  50000.00000    50000.000000
# mean    2954.565580    369.187220    162.306760    177.22878      592.695960
# min       40.000000      2.000000      0.000000      1.00000        7.000000
# ...
